# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1000

x = np.random.uniform(size=n)

plt.hist(x,bins=100,alpha=0.5,edgecolor="black")
plt.ylabel("Amount per bin")
plt.xlabel("x")
plt.savefig("histogram.pdf",bbox_inches="tight",facecolor="white")
# Out:
# Text(0.5, 0, 'x')
